# %% [markdown]
# Note: Download data if running for the first time or if you get an error message.

# %%
import numpy as np

from bokeh.plotting import figure, show, output_file, output_notebook

N = 4000
x = np.random.random(size=N) * 100
y = np.random.random(size=N) * 100
radii = np.random.random(size=N) * 1.5
colors = [
    "#%02x%02x%02x" % (int(r), int(g), 150) for r, g in zip(50+2*x, 30+2*y)
]

TOOLS="resize,crosshair,pan,wheel_zoom,box_zoom,undo,redo,reset,tap,previewsave,box_select,poly_select,lasso_select"

p = figure(tools=TOOLS)

p.scatter(x, y, radius=radii,
          fill_color=colors, fill_alpha=0.6,
          line_color=None)
output_notebook()
show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="0602e916-f976-4486-a8be-96970a3a8a49">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="plotdiv" id="790a343b-1318-4296-b160-09fce25055a6"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("790a343b-1318-4296-b160-09fce25055a6");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '790a343b-1318-4296-b160-09fce25055a6' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"1a52a866-bbb6-4af7-ae24-d310de2f8cbb":{"roots":{"references":[{"attributes":{"callback":null},"id":"d58bae50-8927-45ed-a132-38a503b9cac3","type":"DataRange1d"},{"attributes":{"plot":{"id":"46a35ed7-6bcd-4a3b-bc66-81d886ef7db9","subtype":"Figure","type":"Plot"}},"id":"7c2678d2-bafa-4288-902b-c27bcb7a1ce5","type":"RedoTool"},{"attributes":{"fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"xs_units":"screen","ys_units":"screen"},"id":"744830d4-1254-4b93-8e39-496252867ba9","type":"PolyAnnotation"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"7224b7f6-0d4a-44d6-bf4b-33ef69c17b85","type":"BoxAnnotation"},{"attributes":{"callback":null,"overlay":{"id":"72f8dd07-be5c-4e17-9ba5-b03a75a5f829","type":"PolyAnnotation"},"plot":{"id":"46a35ed7-6bcd-4a3b-bc66-81d886ef7db9","subtype":"Figure","type":"Plot"}},"id":"9ca59d04-f286-47c2-9fd3-825cbe1479b6","type":"LassoSelectTool"},{"attributes":{"overlay":{"id":"744830d4-1254-4b93-8e39-496252867ba9","type":"PolyAnnotation"},"plot":{"id":"46a35ed7-6bcd-4a3b-bc66-81d886ef7db9","subtype":"Figure","type":"Plot"}},"id":"4bc2764d-1c09-447f-a655-db28a720d4eb","type":"PolySelectTool"},{"attributes":{"dimension":1,"plot":{"id":"46a35ed7-6bcd-4a3b-bc66-81d886ef7db9","subtype":"Figure","type":"Plot"},"ticker":{"id":"6add2ea8-e546-429d-94ab-1255eac5e31d","type":"BasicTicker"}},"id